# %% [markdown]
# ## Tensor Fundamentals
# #### Trying to master PyTorch tensors - The foundation of everything

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
torch.cuda.is_available()
# Out:
# True
